# %% [markdown]
# Exercício 1
# Crie um programa que mostre na tela:

# %%
a = "Eu estou aprendendo Python"
print(a)
# Out:
# Eu estou aprendendo Python

# %% [markdown]
# Exercício 2
# Crie um programa que mostre:

# %%
a="João Pedro"
b="Goiânia"
print("Meu nome é", a)
print("Eu moro em", b)
# Out:
# Meu nome é João Pedro
# Eu moro em Goiânia

# %% [markdown]
# Exercício 3
# Crie duas variáveis: nome_do_aluno e idade_do_aluno.
# Depois mostre na tela algo assim:

# %%
nome_do_aluno="João"
idade_do_aluno=17
print("Meu nome é", nome_do_aluno, "e tenho", idade_do_aluno, "anos")
# Out:
# Meu nome é João e tenho 17 anos

# %% [markdown]
# Exercício 4 (Desafio Extra)
# Crie três variáveis: cidade, estado e pais.

# %%
c= "Valparaiso de Goiás"
e="- GO"
p="Brasil"
print("Nasci e fui criado em", c, e, "que fica na República federativa do", p)
# Out:
# Nasci e fui criado em Valparaiso de Goiás - GO que fica na República federativa do Brasil

# %% [markdown]
# Crie um programa que:
# 1. Pergunte o nome do aluno.
# 2. Pergunte a cidade onde ele mora.
# 3. Mostre a frase:
#
# Olá João, você mora em Curitiba

# %%
nome_aluno=input("Qual o seu nome? ")
cidade_aluno=input("Qual a cidade em que você mora? ")
print("Olá,", nome_aluno, "você mora em", cidade_aluno)
# Out:
# Qual o seu nome?  João Pedro
# Qual a cidade em que você mora?  Goiânia
# Olá, João Pedro você mora em Goiânia
